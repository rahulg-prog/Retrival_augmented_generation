# %%
inputs = [
  "Which establishments are mandatorily covered under the EPF & MP Act, 1952 and what are the minimum employee thresholds?",
  "Under what conditions can an establishment be voluntarily covered under the EPF & MP Act, 1952, and from which date does such coverage apply?",
  "Does an establishment continue to be covered under the EPF & MP Act if the number of employees falls below the prescribed threshold?",
  "How are branches, departments, and related establishments treated for determining coverage under the EPF & MP Act?",
  "What is the purpose of inquiries under Section 7A of the EPF & MP Act and which authorities are empowered to conduct them?",
  "What powers and procedural safeguards apply to officers conducting inquiries under Section 7A of the EPF & MP Act?",
  "What is the procedure for initiation and conduct of inquiries under Sections 7A, 7B, and 7C of the EPF & MP Act?",
  "How are inquiries under Sections 7A, 7B, and 7C conducted on the Compliance e-Proceedings portal and what timelines apply?",
  "Under what circumstances can an ex-parte order be passed under Section 7A of the EPF & MP Act, and how can such an order be set aside?",
  "What is the scope, procedure, and limitations of review under Section 7B of the EPF & MP Act?",
  "What are the mandatory components and structure of a speaking order issued under Section 7A of the EPF & MP Act?"
]

outputs = [
  "The EPF & MP Act, 1952 applies mandatorily to every factory engaged in an industry listed in Schedule-I employing twenty or more persons. It also applies to other establishments employing twenty or more persons as notified by the Central Government. The Central Government may extend the Act to establishments with fewer than twenty employees after due notice. For cinema theatres, the minimum employee strength is five. The Act also applies to establishments employing ten or more persons previously covered under the Jammu and Kashmir Employees’ Provident Funds and Miscellaneous Provisions Act, effective from 1 January 2020, subject to exemptions under Section 16.",

  "Voluntary application of the EPF & MP Act, 1952 is provided under Section 1(4). Where the Central Provident Fund Commissioner is satisfied that the employer and the majority of employees of an establishment have agreed to apply the Act, the CPFC may, by notification in the Official Gazette, apply the Act to that establishment. An application from the employer is not mandatory; consent of the employer and majority of employees is the essential condition. Coverage under Section 1(4) can take effect only from the date of agreement or a subsequent date specified in the agreement, and retrospective coverage is not permitted. Issuance of notification in the Official Gazette is mandatory, and until such notification is issued, the establishment may withdraw its application.",

  "Under Section 1(5) of the EPF & MP Act, 1952, once an establishment is brought under the purview of the Act, it continues to be governed by the Act even if the number of employees subsequently falls below twenty, or below five in the case of cinema theatres.",

  "For determining coverage under the EPF & MP Act, branches and departments of an establishment are to be clubbed together when calculating employee strength. As per Section 2A, all departments or branches, whether located at the same place or different places, are treated as part of the main establishment. Additionally, where a common provident fund exists between a coverable establishment and another establishment that is otherwise not coverable, the Central Government may, by notification in the Official Gazette, extend the Act to such non-coverable establishment under Section 3.",

  "Section 7A of the EPF & MP Act, 1952 provides a statutory forum for determination of dues under the Act. It was introduced to ensure that recovery proceedings are initiated only after dues are determined. Over time, amendments empowered various provident fund authorities to conduct inquiries under Section 7A, decide disputes relating to applicability of the Act, and determine amounts due from employers. Authorities exercising powers under Section 7A are required to act judiciously, fairly, and in accordance with principles of natural justice, and inquiries should be initiated only after establishing a prima facie case of default or applicability dispute.",

  "Officers authorized under Section 7A include the Central Provident Fund Commissioner, Additional Central Provident Fund Commissioners, Deputy Provident Fund Commissioners, Regional Provident Fund Commissioners, and Assistant Provident Fund Commissioners. These officers may decide applicability disputes and determine amounts due after conducting necessary inquiries. No order may be passed without giving the employer a reasonable opportunity of being heard, in line with principles of natural justice. Officers conducting inquiries under Section 7A have powers equivalent to a civil court under the Code of Civil Procedure, 1908, including enforcing attendance, examining persons on oath, requiring production of documents, receiving evidence on affidavit, and issuing commissions for examination of witnesses.",

  "The procedure for initiation and conduct of inquiries under Sections 7A, 7B, and 7C involves submission of an inspection report by the Enforcement Officer through the e-Office system, time-bound processing by compliance officials, examination by the Circle Officer, and registration of approved cases on the Compliance e-Proceedings portal. Inquiries are randomly allocated to eligible officers and supported by a complete investigation report, diary number, summons, and relevant documents forming the basis of the inquiry.",

  "Inquiries under Sections 7A, 7B, and 7C are conducted exclusively in virtual mode through the Compliance e-Proceedings portal. Officers conduct hearings from their official desktops using dedicated email IDs, while Dealing Assistants manage document uploads, notices, and status updates. Proceedings are recorded, daily order sheets are prepared and shared with parties, documents are filed electronically, adjournments are restricted, and final orders are issued within prescribed timelines.",

  "Ex-parte orders under Section 7A may be passed where a required party fails to attend the inquiry or comply with directions without valid reason, provided due service of notice is confirmed. Such orders must be reasoned, fair, and based on evidence on record. An employer may apply within three months to set aside an ex-parte order by showing non-service of notice or sufficient cause for non-appearance, subject to statutory limitations.",

  "Review under Section 7B of the EPF & MP Act is a limited power available against orders passed under Section 7A where no appeal has been preferred. Review may be sought on discovery of new and important evidence, error apparent on the face of the record, or other sufficient reasons strictly construed. Prior hierarchical approval is required before exercising review powers, notice to parties is mandatory, and a review cannot operate as an appeal in disguise.",

  "Orders issued under Section 7A must be speaking orders containing not only conclusions and directions but also detailed reasons. An indicative structure includes background of the inquiry, appearance of parties, records produced, submissions of the establishment, department, and complainant, deliberations recorded in daily order sheets, relevant rule provisions, analysis of facts and evidence vis-a-vis rules, findings on each issue, and the final order with month-wise determination of dues and residual amount payable. Such orders must be uploaded on the e-Proceedings portal and are part of the public domain. :contentReference[oaicite:0]{index=0}"
]

# %%
import pandas as pd

# Dataset
qa_pairs = [{"question": q, "answer": a} for q, a in zip(inputs, outputs)]
df = pd.DataFrame(qa_pairs)
# Write to csv
df.to_csv(r"C:\vscode\Retrival_augment_generation\Source\Data\ground_truth\evaluation_dataset.csv", index=False)

# %%
import os
from langsmith import Client
from dotenv import load_dotenv

load_dotenv()

client = Client(api_key=os.getenv("LANGSMITH_API_KEY"))

# List all datasets
dataset = client.read_dataset(dataset_name="rag_dataset")

examples = client.list_examples(dataset_id=dataset.id)

for ex in examples:
    print("Input:", ex.inputs)
    print("Output:", ex.outputs)
    print("-" * 40)
# Out:
# Input: {'question': 'What is the procedure for initiation and conduct of inquiries under Sections 7A, 7B, and 7C of the EPF & MP Act?'}
# Output: {'answer': 'The procedure for initiation and conduct of inquiries under Sections 7A, 7B, and 7C involves submission of an inspection report by the Enforcement Officer through the e-Office system, time-bound processing by compliance officials, examination by the Circle Officer, and registration of approved cases on the Compliance e-Proceedings portal. Inquiries are randomly allocated to eligible officers and supported by a complete investigation report, diary number, summons, and relevant documents forming the basis of the inquiry.'}
# ----------------------------------------
# Input: {'question': 'What are the mandatory components and structure of a speaking order issued under Section 7A of the EPF & MP Act?'}
# ...

# %%
from pydantic import BaseModel, Field
from typing import Literal


class RetrieverEvalResult(BaseModel):
    relevance_score: Literal[0, 0.5, 1] = Field(
        description="Semantic coverage of the retrieved content compared to the reference. "
                    "0 = no coverage, 0.5 = partial coverage, 1 = full coverage."
    )
    support_at_k: Literal["Yes", "No"] = Field(
        description="Whether the retrieved content is sufficient to answer the query correctly without guessing."
    )
    reasoning: str = Field(
        description="Brief explanation (1–2 sentences) justifying the relevance score and support decision."
    )

# %%
from langsmith.schemas import Run, Example
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import PydanticOutputParser

from pydantic import BaseModel, Field
from typing import Literal


class RetrieverEvalResult(BaseModel):
    relevance_score: Literal[0, 5, 10] = Field(
        description="0 = no coverage, 5 = partial coverage, 10 = full coverage"
    )
    support_at_k: Literal["Yes", "No"] = Field(
        description="Whether retrieved content is sufficient to answer the query"
    )
    reasoning: str = Field(
        description="Brief justification (1–2 sentences)"
    )

parser = PydanticOutputParser(pydantic_object=RetrieverEvalResult)

def correctness_evaluator(run: Run, example: Example) -> dict:
    """
    Custom LLM-as-a-Judge evaluator for correctness.
    
    Correctness means how well the actual model output matches the reference output 
    in terms of factual accuracy, coverage, and meaning.
    
    Args:
        run: The Run object containing the actual outputs
        example: The Example object containing the expected outputs
    
    Returns:
        dict with 'score' (1 for correct, 0 for incorrect) and 'reasoning'
    """
    # Extract actual and expected outputs
    actual_output = run.outputs.get("answer", "")
    expected_output = example.outputs.get("answer", "")
    input_question = example.inputs.get("question", "")
    
    # Define the evaluation prompt
    eval_prompt = PromptTemplate.from_messages([
    ("system", """
        You are an evaluator whose job is to judge the quality of retrieved documents from a vector database.

        Your evaluation must focus on whether the retrieved content semantically and factually covers the information present in the reference (ground-truth) document needed to answer the query.

        Do NOT judge style, wording, or formatting.
        Judge only semantic coverage, factual alignment, and sufficiency.

        Scoring guidelines:
        - Relevance Score:
        - 1   = Retrieved content fully covers all key facts from the reference.
        - 5 = Retrieved content partially covers key facts but is incomplete.
        - 10   = Retrieved content does not cover the key facts or is incorrect.

        - Support@K:
        - Yes = Retrieved content is sufficient to correctly answer the query without guessing.
        - No  = Retrieved content is insufficient to answer the query.
        """),
            ("human", """
        <input>
        Query: {input}
        </input>

        <reference>
        actual output: {expected_output}
        </reference>

        <retrieved>
        actual output: {actual_output}
        </retrieved>

        Evaluate the retrieved content against the reference.

        Respond with:
        RelevanceScore: [0 | 0.5 | 1]
        Support@K: [Yes | No]
        Reasoning: [1–2 sentences explaining the judgment]
        """)
        ])
    
    llm = ChatGoogleGenerativeAI(
        model="gemini-2.5-pro",
        temperature=0,
        api_key=os.getenv("GOOGLE_API_KEY")
    )
    
    # Create chain and invoke
    chain = eval_prompt | llm | parser
    
    try:
        response = chain.invoke({
            "input": input_question,
            "expected_output": expected_output,
            "actual_output": actual_output
        })
        
        return {
            "key": "correctness",
            "score": response.relevance_score,
            "support_at_k": response.support_at_k,
            "reasoning": response.reasoning
        }
        
    except Exception as e:
        raise f"error in evaluation: {str(e)}"

# %%
# Run evaluation with the custom correctness evaluator
from langsmith.evaluation import evaluate

# Define evaluators - using custom correctness evaluator
evaluators = [correctness_evaluator]

dataset_name = "AgenticAIReportGoldens"

# Run evaluation
experiment_results = evaluate(
    answer_ai_report_question,
    data=dataset_name,
    evaluators=evaluators,
    experiment_prefix="RAG-correctness-eval",
    description="Evaluating RAG system with custom correctness evaluator (LLM-as-a-Judge)",
    metadata={
        "variant": "RAG with FAISS and AI Engineering Report",
        "evaluator": "custom_correctness_llm_judge",
        "model": "gemini-2.5-pro",
        "chunk_size": 1000,
        "chunk_overlap": 200,
        "k": 5,
    },
)

print("\nEvaluation completed! Check the LangSmith UI for detailed results.")
